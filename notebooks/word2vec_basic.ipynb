# %% [markdown]
# # Word2vec basic

# %%
import collections
import math
import os
import random
import zipfile
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline  
print ("Packages loaded")
# Out:
# Packages loaded

# %% [markdown]
# # 1. Download the text and make corpus (set of words)

# %% [markdown]
# ## Download (or reuse) the text file that we will use

# %%
folder_dir  = "data"
file_name   = "text8.zip"
file_path   = os.path.join(folder_dir, file_name)
url         = 'http://mattmahoney.net/dc/'
if not os.path.exists(file_path):
    print ("No file found. Start downloading")
    downfilename, _ = urllib.request.urlretrieve(
        url + file_name, file_path)
    print ("'%s' downloaded" % (downfilename))
else:
    print ("File already exists")
# Out:
# File already exists

# %% [markdown]
# ## Check we have correct data

# %%
statinfo = os.stat(file_path)
expected_bytes = 31344016
if statinfo.st_size == expected_bytes:
    print ("I guess we have correct file at '%s'" % (file_path))
else:
    print ("Something's wrong with the file at '%s'" % (file_path))
# Out:
# I guess we have correct file at 'data/text8.zip'

# %% [markdown]
# ## Unzip the file

# %%
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = f.read(f.namelist()[0]).split()
    return data

# %%
words = read_data(file_path) 
print ("Type of 'words' is %s / Length is %d " 
       % (type(words), len(words)))
print ("'words' look like \n %s" %(words[0:1000]))
# Out:
# Type of 'words' is <type 'list'> / Length is 17005207
# 'words' look like
#  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'society', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'to', 'economics', 'there', 'is', 'also', 'disagreement', 'about', 'how', 'a', 'free', 'society', 'might', 'be', 'brought', 'about', 'origins', 'and', 'predecessors', 'kropotkin', 'and', 'others', 'argue', 'that', 'before', 'recorded', 'history', 'human', 'society', 'was', 'organized', 'on', 'anarchist', 'principles', 'most', 'anthropologists', 'follow', 'kropotkin', 'and', 'engels', 'in', 'believing', 'that', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'and', 'lacked', 'division', 'of', 'labour', 'accumulated', 'wealth', 'or', 'decreed', 'law', 'and', 'had', 'equal', 'access', 'to', 'resources', 'william', 'godwin', 'anarchists', 'including', 'the', 'the', 'anarchy', 'organisation', 'and', 'rothbard', 'find', 'anarchist', 'attitudes', 'in', 'taoism', 'from', 'ancient', 'china', 'kropotkin', 'found', 'similar', 'ideas', 'in', 'stoic', 'zeno', 'of', 'citium', 'according', 'to', 'kropotkin', 'zeno', 'repudiated', 'the', 'omnipotence', 'of', 'the', 'state', 'its', 'intervention', 'and', 'regimentation', 'and', 'proclaimed', 'the', 'sovereignty', 'of', 'the', 'moral', 'law', 'of', 'the', 'individual', 'the', 'anabaptists', 'of', 'one', 'six', 'th', 'century', 'europe', 'are', 'sometimes', 'considered', 'to', 'be', 'religious', 'forerunners', 'of', 'modern', 'anarchism', 'bertrand', 'russell', 'in', 'his', 'history', 'of', 'western', 'philosophy', 'writes', 'that', 'the', 'anabaptists', 'repudiated', 'all', 'law', 'since', 'they', 'held', 'that', 'the', 'good', 'man', 'will', 'be', 'guided', 'at', 'every', 'moment', 'by', 'the', 'holy', 'spirit', 'from', 'this', 'premise', 'they', 'arrive', 'at', 'communism', 'the', 'diggers', 'or', 'true', 'levellers', 'were', 'an', 'early', 'communistic', 'movement', 'during', 'the', 'time', 'of', 'the', 'english', 'civil', 'war', 'and', 'are', 'considered', 'by', 'some', 'as', 'forerunners', 'of', 'modern', 'anarchism', 'in', 'the', 'modern', 'era', 'the', 'first', 'to', 'use', 'the', 'term', 'to', 'mean' ...

# %% [markdown]
# # 2. Make a dictionary with fixed length (using UNK token)

# %% [markdown]
# ## Count the words

# %%
vocabulary_size = 50000 
count = [['UNK', -1]] 
count.extend(collections.Counter(words)
             .most_common(vocabulary_size - 1)) # -1 is for UNK 
print ("Type of 'count' is %s / Length is %d " % (type(count), len(count)))
print ("'count' looks like \n %s" % (count[0:10]))
# Out:
# Type of 'count' is <type 'list'> / Length is 50000
# 'count' looks like
#  [['UNK', -1], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]

# %% [markdown]
# ## Make a dictionary

# %%
dictionary = dict() 
for word, _ in count:
    dictionary[word] = len(dictionary)
print ("Type of 'dictionary' is %s / Length is %d " 
       % (type(dictionary), len(dictionary)))
# Out:
# Type of 'dictionary' is <type 'dict'> / Length is 50000

# %%
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
print ("Type of 'reverse_dictionary' is %s / Length is %d " 
       % (type(reverse_dictionary), len(reverse_dictionary)))
# Out:
# Type of 'reverse_dictionary' is <type 'dict'> / Length is 50000

# %% [markdown]
# ## Make data

# %%
data = list()
unk_count = 0
for word in words:
    if word in dictionary:
        index = dictionary[word]
    else:
        index = 0  # dictionary['UNK']
        unk_count += 1
    data.append(index)
count[0][1] = unk_count
# del words  # Hint to reduce memory.

# %% [markdown]
# ### 'dictionary' converts word to index
# ### 'reverse_dictionary' converts index to word

# %%
print ("Most common words (+UNK) are: %s" % (count[:5]))
# Out:
# Most common words (+UNK) are: [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]

# %%
print ("Sample data: %s" % (data[:10]))
# Out:
# Sample data: [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print ("Sample data corresponds to\n__________________")
for i in range(10):
    print ("%d->%s" % (data[i], reverse_dictionary[data[i]]))
# Out:
# Sample data corresponds to
# __________________
# 5239->anarchism
# 3084->originated
# 12->as
# 6->a
# 195->term
# 2->of
# 3137->abuse
# 46->first
# 59->used
# 156->against

# %% [markdown]
# # Batch-generating function for skip-gram model
# ## - Skip-gram (one word to one word) => Can generate more training data
#
# <img src="images/etc/word2vec_desc.png">

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch  = np.ndarray(shape=(batch_size),    dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips): # '//' makes the result an integer, e.g., 7//3 = 2
        target = skip_window
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %% [markdown]
# ### Examples for generating batch and labels

# %%
data_index = 0
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
print ("Type of 'batch' is %s / Length is %d " 
       % (type(batch), len(batch))) 
print ("Type of 'labels' is %s / Length is %d " 
       % (type(labels), len(labels)))
# Out:
# Type of 'batch' is <type 'numpy.ndarray'> / Length is 8
# Type of 'labels' is <type 'numpy.ndarray'> / Length is 8

# %%
print ("'batch' looks like \n %s" % (batch))
# Out:
# 'batch' looks like
#  [3084 3084   12   12    6    6  195  195]

# %%
print ("'labels' looks like \n %s" % (labels))
# Out:
# 'labels' looks like
#  [[  12]
#  [5239]
#  [3084]
#  [   6]
#  [ 195]
#  [  12]
#  [   6]
#  [   2]]

# %%
for i in range(8):
    print ("%d -> %d" 
           % (batch[i], labels[i, 0])),
    print ("\t%s -> %s" 
           % (reverse_dictionary[batch[i]]
              , reverse_dictionary[labels[i, 0]]))
# Out:
# 3084 -> 12 	originated -> as
# 3084 -> 5239 	originated -> anarchism
# 12 -> 3084 	as -> originated
# 12 -> 6 	as -> a
# 6 -> 195 	a -> term
# 6 -> 12 	a -> as
# 195 -> 6 	term -> a
# 195 -> 2 	term -> of

# %% [markdown]
# # 3. Build a Skip-Gram Model

# %%
batch_size     = 128
embedding_size = 128       # Dimension of the embedding vector.
skip_window    = 1         # How many words to consider left and right.
num_skips      = 2         # How many times to reuse an input 
print ("Parameters ready")
# Out:
# Parameters ready

# %%
# Random validation set to sample nearest neighbors.
valid_size     = 32        # Random set of words to evaluate similarity 
valid_window   = 200       # Only pick dev samples in the head 
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

print (valid_examples)
# Out:
# [145   6  47 129  88 140 199  31  67  65  86   0  73  45 156  42  32  19
#   92  35  96 116  17 137   4  98  14 185 184 164  94  26]

# %% [markdown]
# # Define network

# %%
# Construct the word2vec model 
train_inputs   = tf.placeholder(tf.int32, shape=[batch_size])   
train_labels   = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset  = tf.constant(valid_examples, dtype=tf.int32)

# Look up embeddings for inputs. (vocabulary_size = 50,000)
with tf.variable_scope("EMBEDDING"):
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size]
                              , -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
    
# Construct the variables for the NCE loss
with tf.variable_scope("NCE_WEIGHT"):
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
print ("Network ready")
# Out:
# Network ready

# %% [markdown]
# # Define functions

# %%
with tf.device('/cpu:0'):
    # Loss function 
    num_sampled = 64        # Number of negative examples to sample. 
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, embed
                       , train_labels, num_sampled, vocabulary_size))
    # Optimizer
    optm = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
    # Similarity measure (important)
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings
                    , valid_dataset)
    siml = tf.matmul(valid_embeddings, normalized_embeddings
                    , transpose_b=True)
    
print ("Functions Ready")
# Out:
# Functions Ready

# %% [markdown]
# # 4. Train a Skip-Gram Model

# %%
# Train! 
sess = tf.Session()
sess.run(tf.initialize_all_variables())
summary_writer = tf.train.SummaryWriter('/tmp/tf_logs/word2vec', graph=sess.graph)
average_loss = 0

num_steps = 100001
for iter in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}
    _, loss_val = sess.run([optm, loss], feed_dict=feed_dict)
    average_loss += loss_val
    
    if iter % 2000 == 0:
        average_loss /= 2000
        print ("Average loss at step %d is %.3f" % (iter, average_loss)) 
    
    if iter % 10000 == 0:
        siml_val = sess.run(siml)
        for i in xrange(valid_size): # Among valid set 
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 6 # number of nearest neighbors
            nearest = (-siml_val[i, :]).argsort()[1:top_k+1]
            log_str = "Nearest to '%s':" % valid_word
            for k in xrange(top_k):
                close_word = reverse_dictionary[nearest[k]] 
                log_str = "%s '%s'," % (log_str, close_word)
            print(log_str) 
            
# Final embeding 
final_embeddings = sess.run(normalized_embeddings)
# Out:
# Average loss at step 0 is 0.142
# Nearest to 'john': 'donatello', 'preseason', 'ceuta', 'fripp', 'electrochemical', 'rubidium',
# Nearest to 'a': 'pathogens', 'averroes', 'spinal', 'tierra', 'neon', 'jainism',
# Nearest to 'they': 'sorceress', 'weekend', 'arches', 'melodies', 'bianchi', 'isdn',
# Nearest to 'life': 'hyper', 'paullus', 'zach', 'dissident', 'unfashionable', 'treasury',
# Nearest to 'if': 'triggering', 'mise', 'sweden', 'avc', 'copley', 'immunology',
# Nearest to 'work': 'every', 'lavon', 'intervened', 'kaunda', 'fasttrack', 'rommel',
# Nearest to 'found': 'graveyard', 'algebraic', 'unfavorable', 'galante', 'muralitharan', 'concluding',
# Nearest to 'an': 'filthy', 'discontinuity', 'brokers', 'octal', 'incarnation', 'kate',
# Nearest to 'only': 'chr', 'synthesizing', 'pathologies', 'cynics', 'christened', 'kri',
# Nearest to 'time': 'siemens', 'blackpool', 'gabonese', 'parachutes', 'dissonant', 'jordanes',
# Nearest to 'united': 'fusion', 'laser', 'were', 'floats', 'anguilla', 'sidelines',
# Nearest to 'UNK': 'refering', 'transgendered', 'chronicler', 'posited', 'courson', 'tottenham',
# Nearest to 'b': 'lever', 'gte', 'kao', 'longinus', 'retake', 'leone',
# Nearest to 'its': 'tivoli', 'trout', 'suckling', 'own', 'subseteq', 'correspondents',
# Nearest to 'against': 'rearrange', 'landmasses', 'specialized', 'punishments', 'browns', 'tamed',
# Nearest to 'but': 'tricky', 'circled', 'tech', 'significantly', 'djibouti', 'ocs',
# Nearest to 'be': 'exploits', 'functionalist', 'mango', 'prosecution', 'martial', 'galindo',
# Nearest to 'by': 'infante', 'ascendant', 'asparagus', 'strathclyde', 'inaugural', 'freehold',
# Nearest to 'system': 'mutual', 'pubmed', 'livin', 'cached', 'pca', 'climatology',
# Nearest to 'at': 'correlated', 'unconventional', 'masked', 'sakharov', 'partisan', 'aford',
# Nearest to 'history': 'bede', 'rudolph', 'fishing', 'adin', 'degree', 'cabling',
# Nearest to 'm': 'ieee', 'elisha', 'eyes', 'decorating', 'avi', 'ere',
# Nearest to 'three': 'turin', 'eek', 'heretofore', 'linguistics', 'justifying', 'counterculture',
# Nearest to 'day': 'garner', 'returning', 'candide', 'roderick', 'cav', 'supernova',
# Nearest to 'one': 'lineage', 'newsstand', 'christoph', 'permutation', 'tsu', 'satrap',
# Nearest to 'up': 'lata', 'supercharger', 'depositing', 'compromised', 'automaker', 'irons',
# Nearest to 'for': 'grenoble', 'periodically', 'aes', 'supercomputing', 'cellini', 'relapsed',
# Nearest to 'long': 'cricketing', 'generators', 'interlingua', 'foetus', 'safin', 'warfield',
# Nearest to 'power': 'thief', 'eclectic', 'germaine', 'macrobiotics', 'schiavo', 'herb',
# Nearest to 'second': 'schaefer', 'versailles', 'deccan', 'apollonia', 'musab', 'ineffective',
# Nearest to 'state': 'gonna', 'adolfo', 'neuroscientists', 'kms', 'rectangles', 'ridiculous',
# Nearest to 'are': 'favourites', 'intersections', 'anglicans', 'injector', 'den', 'bullough',
# Average loss at step 2000 is 114.001
# Average loss at step 4000 is 52.523
# Average loss at step 6000 is 33.362
# Average loss at step 8000 is 23.787
# Average loss at step 10000 is 17.987
# Nearest to 'john': 'easily', 'an', 'attendance', 'coach', 'seen', 'chose',
# Nearest to 'a': 'the', 'UNK', 'one', 'sagan', 'and', 'aberdeen',
# Nearest to 'they': 'he', 'tubing', 'weekend', 'richmond', 'limits', 'arches',
# Nearest to 'life': 'zach', 'architectural', 'hyper', 'dissident', 'asperger', 'treasury',
# Nearest to 'if': 'sweden', 'triggering', 'mise', 'opposition', 'version', 'ayer',
# Nearest to 'work': 'intervened', 'every', 'asparagales', 'vs', 'meant', 'consider',
# Nearest to 'found': 'reginae', 'washington', 'algebraic', 'neck', 'salinity', 'graveyard',
# Nearest to 'an': 'the', 'john', 'a', 'linebackers', 'newspaper', 'psycho',
# Nearest to 'only': 'agave', 'especially', 'austin', 'precise', 'success', 'eclectic',
# Nearest to 'time': 'aberdeen', 'parachutes', 'while', 'examination', 'shoot', 'austin',
# Nearest to 'united': 'victoriae', 'fusion', 'hephaestion', 'northern', 'responded', 'might',
# Nearest to 'UNK': 'one', 'and', 'victoriae', 'austin', 'cl', 'vs',
# Nearest to 'b': 'swiss', 'players', 'ways', 'kilometres', 'lot', 'leone',
# Nearest to 'its': 'austin', 'amphibians', 'cl', 'elected', 'forces', 'strains',
# Nearest to 'against': 'specialized', 'cc', 'respect', 'lasted', 'browns', 'punishments',
# Nearest to 'but': 'significantly', 'tech', 'blood', 'folly', 'world', 'patent',
# Nearest to 'be': 'prosecution', 'martial', 'exploits', 'have', 'is', 'aleister',
# Nearest to 'by': 'in', 'and', 'with', 'of', 'is', 'as',
# Nearest to 'system': 'staff', 'mutual', 'alien', 'fires', 'attempt', 'logic',
# Nearest to 'at': 'in', 'agave', 'of', 'vs', 'mathbf', 'and',
# Nearest to 'history': 'rudolph', 'fishing', 'austin', 'cl', 'degree', 'supported',
# Nearest to 'm': 'eyes', 'hydrochloric', 'gb', 'libya', 'analogue', 'subclass',
# Nearest to 'three': 'zero', 'austin', 'five', 'basins', 'six', 'cl',
# Nearest to 'day': 'returning', 'victoriae', 'server', 'close', 'coup', 'techniques',
# Nearest to 'one': 'austin', 'two', 'UNK', 'cl', 'gland', 'gollancz',
# Nearest to 'up': 'vs', 'gland', 'pauline', 'millions', 'goal', 'andrew',
# Nearest to 'for': 'and', 'in', 'of', 'cl', 'with', 'hans',
# Nearest to 'long': 'ram', 'reginae', 'er', 'kg', 'related', 'boroughs',
# Nearest to 'power': 'thief', 'events', 'altenberg', 'moon', 'criteria', 'currently',
# Nearest to 'second': 'versailles', 'gland', 'arguments', 'agave', 'austin', 'mauss',
# Nearest to 'state': 'gonna', 'laid', 'victoriae', 'phil', 'pleasant', 'basins',
# Nearest to 'are': 'is', 'probably', 'has', 'panel', 'cl', 'were',
# Average loss at step 12000 is 13.982
# Average loss at step 14000 is 11.656
# Average loss at step 16000 is 9.907
# Average loss at step 18000 is 8.642
# Average loss at step 20000 is 7.855
# Nearest to 'john': 'easily', 'an', 'jacksonville', 'seven', 'monasticism', 'attendance',
# Nearest to 'a': 'the', 'annales', 'their', 'his', 'reginae', 'incompressible',
# Nearest to 'they': 'he', 'animists', 'also', 'dasyprocta', 'tubing', 'agouti',
# Nearest to 'life': 'hyper', 'zach', 'treasury', 'dissident', 'architectural', 'worshipped',
# Nearest to 'if': 'sweden', 'but', 'is', 'when', 'mise', 'opposition',
# Nearest to 'work': 'dasyprocta', 'intervened', 'agouti', 'meant', 'asparagales', 'every',
# Nearest to 'found': 'reginae', 'salinity', 'neck', 'algebraic', 'graveyard', 'washington',
# Nearest to 'an': 'the', 'dasyprocta', 'john', 'this', 'libertarian', 'reginae',
# Nearest to 'only': 'agave', 'especially', 'agouti', 'aleutians', 'eclectic', 'precise',
# Nearest to 'time': 'adiabatic', 'agouti', 'while', 'parachutes', 'examination', 'dasyprocta',
# Nearest to 'united': 'fusion', 'hephaestion', 'victoriae', 'northern', 'perry', 'responded',
# Nearest to 'UNK': 'schemata', 'dasyprocta', 'victoriae', 'adiabatic', 'agouti', 'and',
# Nearest to 'b': 'd', 'swiss', 'lever', 'english', 'and', 'satisfactory',
# Nearest to 'its': 'the', 'their', 'dasyprocta', 'cl', 'elected', 'his',
# Nearest to 'against': 'specialized', 'punishments', 'landmasses', 'and', 'respect', 'elementary',
# Nearest to 'but': 'and', 'is', 'tech', 'tel', 'see', 'significantly',
# Nearest to 'be': 'have', 'is', 'prosecution', 'martial', 'was', 'dasyprocta',
# Nearest to 'by': 'in', 'was', 'with', 'is', 'from', 'as',
# Nearest to 'system': 'staff', 'mutual', 'alien', 'dasyprocta', 'argo', 'fires',
# Nearest to 'at': 'in', 'and', 'agave', 'for', 'argo', 'aquila',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'fishing', 'travels', 'plate', 'raised',
# Nearest to 'm': 'three', 'hydrochloric', 'six', 'gb', 'zero', 'dasyprocta',
# Nearest to 'three': 'eight', 'five', 'zero', 'six', 'two', 'nine',
# Nearest to 'day': 'returning', 'severely', 'victoriae', 'coup', 'server', 'close',
# Nearest to 'one': 'two', 'dasyprocta', 'eight', 'adiabatic', 'six', 'agouti',
# Nearest to 'up': 'pauline', 'vs', 'dasyprocta', 'andrew', 'millions', 'prefer',
# Nearest to 'for': 'and', 'in', 'with', 'of', 'cl', 'by',
# Nearest to 'long': 'kg', 'er', 'ram', 'lesbian', 'before', 'annales',
# Nearest to 'power': 'dasyprocta', 'albuquerque', 'thief', 'yin', 'moon', 'eclectic',
# Nearest to 'second': 'imran', 'apollonia', 'versailles', 'monarch', 'proposal', 'borders',
# Nearest to 'state': 'gonna', 'laid', 'victoriae', 'agouti', 'dasyprocta', 'phil',
# Nearest to 'are': 'is', 'were', 'was', 'in', 'shirkuh', 'probably',
# Average loss at step 22000 is 7.247
# Average loss at step 24000 is 6.942
# Average loss at step 26000 is 6.591
# Average loss at step 28000 is 6.090
# Average loss at step 30000 is 6.151
# Nearest to 'john': 'easily', 'jacksonville', 'seven', 'attendance', 'lara', 'monasticism',
# Nearest to 'a': 'the', 'annales', 'amalthea', 'incompressible', 'aorta', 'headquarters',
# Nearest to 'they': 'he', 'we', 'animists', 'also', 'dasyprocta', 'not',
# Nearest to 'life': 'hyper', 'zach', 'treasury', 'dissident', 'worshipped', 'architectural',
# Nearest to 'if': 'when', 'is', 'but', 'triggering', 'immunology', 'sweden',
# Nearest to 'work': 'dasyprocta', 'intervened', 'agouti', 'otimes', 'meant', 'lumi',
# Nearest to 'found': 'salinity', 'algebraic', 'reginae', 'neck', 'graveyard', 'discarded',
# Nearest to 'an': 'the', 'dasyprocta', 'regarded', 'this', 'filthy', 'reginae',
# Nearest to 'only': 'agave', 'trinomial', 'aosta', 'especially', 'agouti', 'chr',
# Nearest to 'time': 'adiabatic', 'agouti', 'atacama', 'parachutes', 'examination', 'while',
# Nearest to 'united': 'fusion', 'hephaestion', 'northern', 'victoriae', 'perry', 'responded',
# Nearest to 'UNK': 'dasyprocta', 'abet', 'agouti', 'victoriae', 'analogue', 'aquila',
# Nearest to 'b': 'd', 'abet', 'english', 'swiss', 'and', 'satisfactory',
# Nearest to 'its': 'the', 'their', 'his', 'dasyprocta', 'permeable', 'cl',
# Nearest to 'against': 'punishments', 'and', 'specialized', 'landmasses', 'or', 'for',
# Nearest to 'but': 'and', 'see', 'discard', 'aorta', 'is', 'dasyprocta',
# Nearest to 'be': 'have', 'is', 'was', 'prosecution', 'by', 'dasyprocta',
# Nearest to 'by': 'from', 'was', 'in', 'as', 'with', 'for',
# Nearest to 'system': 'staff', 'mutual', 'alien', 'dasyprocta', 'logic', 'argo',
# Nearest to 'at': 'in', 'and', 'agave', 'for', 'from', 'argo',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'plate', 'fishing', 'travels', 'raised',
# Nearest to 'm': 'three', 'hydrochloric', 'shipper', 'five', 'gb', 'six',
# Nearest to 'three': 'five', 'eight', 'six', 'four', 'seven', 'two',
# Nearest to 'day': 'returning', 'severely', 'coup', 'victoriae', 'techniques', 'close',
# Nearest to 'one': 'two', 'four', 'three', 'six', 'eight', 'five',
# Nearest to 'up': 'him', 'pauline', 'them', 'loup', 'vs', 'thr',
# Nearest to 'for': 'in', 'of', 'with', 'and', 'cl', 'or',
# Nearest to 'long': 'otimes', 'abet', 'er', 'ram', 'kg', 'salieri',
# Nearest to 'power': 'dasyprocta', 'thief', 'albuquerque', 'trinomial', 'yin', 'eclectic',
# Nearest to 'second': 'imran', 'apollonia', 'doped', 'deccan', 'clay', 'burnt',
# Nearest to 'state': 'laid', 'gonna', 'victoriae', 'agouti', 'dasyprocta', 'aquila',
# Nearest to 'are': 'were', 'is', 'was', 'aorta', 'shirkuh', 'in',
# Average loss at step 32000 is 5.877
# Average loss at step 34000 is 5.912
# Average loss at step 36000 is 5.712
# Average loss at step 38000 is 5.277
# Average loss at step 40000 is 5.500
# Nearest to 'john': 'easily', 'monasticism', 'lara', 'gerson', 'jacksonville', 'ceuta',
# Nearest to 'a': 'the', 'amalthea', 'annales', 'aorta', 'bottles', 'incompressible',
# Nearest to 'they': 'he', 'we', 'not', 'it', 'animists', 'dasyprocta',
# Nearest to 'life': 'johansen', 'hyper', 'dissident', 'treasury', 'alejandro', 'zach',
# Nearest to 'if': 'when', 'but', 'is', 'lemmy', 'immunology', 'triggering',
# Nearest to 'work': 'dasyprocta', 'intervened', 'agouti', 'lumi', 'otimes', 'emanated',
# Nearest to 'found': 'used', 'asymptotes', 'reginae', 'salinity', 'algebraic', 'discarded',
# Nearest to 'an': 'the', 'dasyprocta', 'cdp', 'lerner', 'regarded', 'filthy',
# Nearest to 'only': 'agave', 'trinomial', 'especially', 'agouti', 'aosta', 'chr',
# Nearest to 'time': 'adiabatic', 'agouti', 'recitative', 'atacama', 'examination', 'parachutes',
# Nearest to 'united': 'fusion', 'hephaestion', 'northern', 'victoriae', 'perry', 'remarried',
# Nearest to 'UNK': 'abet', 'dasyprocta', 'aquila', 'agouti', 'victoriae', 'adiabatic',
# Nearest to 'b': 'd', 'UNK', 'abet', 'swiss', 'lever', 'primigenius',
# Nearest to 'its': 'their', 'the', 'his', 'permeable', 'dasyprocta', 'cl',
# Nearest to 'against': 'punishments', 'specialized', 'during', 'landmasses', 'and', 'tillich',
# Nearest to 'but': 'and', 'see', 'aorta', 'dasyprocta', 'that', 'discard',
# Nearest to 'be': 'have', 'is', 'was', 'by', 'were', 'prosecution',
# Nearest to 'by': 'was', 'from', 'with', 'is', 'as', 'in',
# Nearest to 'system': 'staff', 'mutual', 'entitles', 'logic', 'argo', 'dasyprocta',
# Nearest to 'at': 'in', 'agave', 'for', 'and', 'argo', 'aquila',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'plate', 'UNK', 'travels', 'fishing',
# Nearest to 'm': 'three', 'six', 'shipper', 'eight', 'gb', 'hydrochloric',
# Nearest to 'three': 'five', 'four', 'seven', 'six', 'two', 'eight',
# Nearest to 'day': 'returning', 'severely', 'coup', 'close', 'techniques', 'garner',
# Nearest to 'one': 'two', 'three', 'six', 'four', 'seven', 'five',
# Nearest to 'up': 'him', 'them', 'pauline', 'loup', 'thr', 'dasyprocta',
# Nearest to 'for': 'and', 'cl', 'with', 'in', 'at', 'dasyprocta',
# Nearest to 'long': 'otimes', 'er', 'abet', 'toto', 'ram', 'threats',
# Nearest to 'power': 'dasyprocta', 'thief', 'yin', 'albuquerque', 'trinomial', 'clips',
# Nearest to 'second': 'apollonia', 'imran', 'doped', 'burnt', 'clay', 'lenoir',
# Nearest to 'state': 'gonna', 'laid', 'victoriae', 'agouti', 'dasyprocta', 'leipzig',
# Nearest to 'are': 'were', 'is', 'have', 'was', 'aorta', 'but',
# Average loss at step 42000 is 5.324
# Average loss at step 44000 is 5.278
# Average loss at step 46000 is 5.277
# Average loss at step 48000 is 5.018
# Average loss at step 50000 is 5.168
# Nearest to 'john': 'lara', 'easily', 'one', 'monasticism', 'gerson', 'jacksonville',
# Nearest to 'a': 'the', 'amalthea', 'annales', 'bottles', 'their', 'incompressible',
# Nearest to 'they': 'he', 'we', 'not', 'it', 'there', 'you',
# Nearest to 'life': 'johansen', 'alejandro', 'dissident', 'hyper', 'zach', 'treasury',
# Nearest to 'if': 'when', 'but', 'is', 'bassoons', 'lemmy', 'trolleybus',
# Nearest to 'work': 'dasyprocta', 'agouti', 'intervened', 'trinomial', 'emanated', 'lumi',
# Nearest to 'found': 'used', 'discarded', 'asymptotes', 'algebraic', 'salinity', 'reginae',
# Nearest to 'an': 'the', 'equine', 'filthy', 'cdp', 'desperate', 'dasyprocta',
# Nearest to 'only': 'agave', 'especially', 'trinomial', 'usually', 'agouti', 'aosta',
# Nearest to 'time': 'adiabatic', 'agouti', 'recitative', 'examination', 'atacama', 'dasyprocta',
# Nearest to 'united': 'fusion', 'northern', 'hephaestion', 'victoriae', 'perry', 'remarried',
# Nearest to 'UNK': 'abet', 'dasyprocta', 'aquila', 'agouti', 'adiabatic', 'victoriae',
# Nearest to 'b': 'd', 'abet', 'six', 'carbohydrates', 'swiss', 'vojt',
# Nearest to 'its': 'their', 'his', 'the', 'permeable', 'dasyprocta', 'cl',
# Nearest to 'against': 'punishments', 'during', 'arctos', 'bhagavad', 'specialized', 'and',
# Nearest to 'but': 'and', 'dasyprocta', 'aorta', 'that', 'primigenius', 'see',
# Nearest to 'be': 'have', 'was', 'is', 'were', 'by', 'are',
# Nearest to 'by': 'was', 'from', 'with', 'be', 'seven', 'were',
# Nearest to 'system': 'staff', 'mutual', 'entitles', 'logic', 'voltaic', 'confirm',
# Nearest to 'at': 'in', 'agave', 'nguni', 'argo', 'for', 'from',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'plate', 'fishing', 'travels', 'thumb',
# Nearest to 'm': 'three', 'five', 'hydrochloric', 'shipper', 'gb', 'eight',
# Nearest to 'three': 'four', 'six', 'five', 'seven', 'two', 'eight',
# Nearest to 'day': 'returning', 'severely', 'coup', 'victoriae', 'techniques', 'garner',
# Nearest to 'one': 'two', 'six', 'four', 'eight', 'three', 'seven',
# Nearest to 'up': 'him', 'them', 'thr', 'loup', 'dasyprocta', 'pauline',
# Nearest to 'for': 'cl', 'in', 'from', 'of', 'and', 'or',
# Nearest to 'long': 'otimes', 'er', 'toto', 'before', 'ram', 'threats',
# Nearest to 'power': 'dasyprocta', 'thief', 'trinomial', 'yin', 'albuquerque', 'thibetanus',
# Nearest to 'second': 'apollonia', 'imran', 'doped', 'burnt', 'clay', 'of',
# Nearest to 'state': 'gonna', 'laid', 'victoriae', 'agouti', 'dasyprocta', 'woods',
# Nearest to 'are': 'were', 'is', 'have', 'was', 'shirkuh', 'be',
# Average loss at step 52000 is 5.177
# Average loss at step 54000 is 5.099
# Average loss at step 56000 is 5.055
# Average loss at step 58000 is 5.115
# Average loss at step 60000 is 4.965
# Nearest to 'john': 'lara', 'gerson', 'UNK', 'monasticism', 'easily', 'jacksonville',
# Nearest to 'a': 'the', 'amalthea', 'annales', 'michelob', 'any', 'apatosaurus',
# Nearest to 'they': 'he', 'we', 'there', 'not', 'it', 'you',
# Nearest to 'life': 'johansen', 'alejandro', 'hyper', 'treasury', 'callithrix', 'bakunin',
# Nearest to 'if': 'when', 'but', 'is', 'trolleybus', 'where', 'triggering',
# Nearest to 'work': 'dasyprocta', 'intervened', 'emanated', 'trinomial', 'agouti', 'microcebus',
# Nearest to 'found': 'used', 'microsite', 'discarded', 'asymptotes', 'salinity', 'algebraic',
# Nearest to 'an': 'the', 'filthy', 'equine', 'cdp', 'lerner', 'scheduled',
# Nearest to 'only': 'agave', 'trinomial', 'especially', 'usually', 'agouti', 'bebox',
# Nearest to 'time': 'adiabatic', 'agouti', 'examination', 'recitative', 'dissonant', 'atacama',
# Nearest to 'united': 'fusion', 'hephaestion', 'victoriae', 'northern', 'remarried', 'perry',
# Nearest to 'UNK': 'microcebus', 'callithrix', 'abet', 'wct', 'dasyprocta', 'michelob',
# Nearest to 'b': 'd', 'abet', 'callithrix', 'vojt', 'wct', 'carbohydrates',
# Nearest to 'its': 'their', 'the', 'his', 'permeable', 'dasyprocta', 'tamarin',
# Nearest to 'against': 'punishments', 'during', 'landmasses', 'tillich', 'arctos', 'for',
# Nearest to 'but': 'and', 'callithrix', 'however', 'michelob', 'dasyprocta', 'see',
# Nearest to 'be': 'have', 'been', 'is', 'by', 'were', 'was',
# Nearest to 'by': 'was', 'michelob', 'with', 'from', 'as', 'be',
# Nearest to 'system': 'staff', 'cebus', 'mutual', 'entitles', 'argo', 'callithrix',
# Nearest to 'at': 'in', 'agave', 'aquila', 'for', 'argo', 'nguni',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'tamarin', 'callithrix', 'microcebus', 'fishing',
# Nearest to 'm': 'UNK', 'gb', 'hydrochloric', 'three', 'shipper', 'michelob',
# Nearest to 'three': 'five', 'four', 'six', 'seven', 'two', 'eight',
# Nearest to 'day': 'returning', 'severely', 'timecode', 'coup', 'techniques', 'confluence',
# Nearest to 'one': 'two', 'four', 'three', 'six', 'five', 'seven',
# Nearest to 'up': 'him', 'them', 'thr', 'loup', 'boudica', 'standardised',
# Nearest to 'for': 'cl', 'and', 'of', 'in', 'or', 'adiabatic',
# Nearest to 'long': 'otimes', 'djamena', 'er', 'toto', 'michelob', 'threats',
# Nearest to 'power': 'dasyprocta', 'ssbn', 'thief', 'albuquerque', 'trinomial', 'yin',
# Nearest to 'second': 'apollonia', 'last', 'imran', 'doped', 'burnt', 'clay',
# Nearest to 'state': 'gonna', 'laid', 'tamarin', 'victoriae', 'dasyprocta', 'agouti',
# Nearest to 'are': 'were', 'is', 'have', 'michelob', 'shirkuh', 'aorta',
# Average loss at step 62000 is 4.778
# Average loss at step 64000 is 4.797
# Average loss at step 66000 is 4.980
# Average loss at step 68000 is 4.900
# Average loss at step 70000 is 4.782
# Nearest to 'john': 'UNK', 'lara', 'gerson', 'seven', 'monasticism', 'mishnayot',
# Nearest to 'a': 'the', 'annales', 'amalthea', 'michelob', 'apatosaurus', 'any',
# Nearest to 'they': 'he', 'we', 'there', 'it', 'you', 'not',
# Nearest to 'life': 'johansen', 'alejandro', 'novel', 'hyper', 'bakunin', 'callithrix',
# Nearest to 'if': 'when', 'where', 'is', 'but', 'trolleybus', 'lemmy',
# Nearest to 'work': 'dasyprocta', 'upanija', 'trinomial', 'agouti', 'microcebus', 'intervened',
# Nearest to 'found': 'used', 'microsite', 'discarded', 'reginae', 'salinity', 'cc',
# Nearest to 'an': 'filthy', 'equine', 'the', 'cdp', 'regarded', 'normandy',
# Nearest to 'only': 'agave', 'especially', 'usually', 'trinomial', 'agouti', 'thaler',
# Nearest to 'time': 'adiabatic', 'agouti', 'examination', 'dissonant', 'recitative', 'atacama',
# Nearest to 'united': 'fusion', 'hephaestion', 'victoriae', 'upanija', 'northern', 'mitral',
# Nearest to 'UNK': 'abet', 'callithrix', 'microcebus', 'michelob', 'wct', 'dasyprocta',
# Nearest to 'b': 'd', 'abet', 'seven', 'UNK', 'p', 'callithrix',
# Nearest to 'its': 'their', 'the', 'his', 'permeable', 'dasyprocta', 'tamarin',
# Nearest to 'against': 'for', 'during', 'punishments', 'including', 'tillich', 'landmasses',
# Nearest to 'but': 'and', 'however', 'callithrix', 'michelob', 'dasyprocta', 'thaler',
# Nearest to 'be': 'have', 'been', 'is', 'by', 'were', 'was',
# Nearest to 'by': 'was', 'from', 'be', 'michelob', 'in', 'as',
# Nearest to 'system': 'staff', 'mutual', 'cebus', 'confirm', 'teleprinter', 'entitles',
# Nearest to 'at': 'in', 'agave', 'aquila', 'for', 'imran', 'argo',
# Nearest to 'history': 'rudolph', 'thaler', 'dasyprocta', 'tamarin', 'fishing', 'microcebus',
# Nearest to 'm': 'UNK', 'seven', 'six', 'hydrochloric', 'three', 'gb',
# Nearest to 'three': 'six', 'five', 'four', 'seven', 'two', 'eight',
# Nearest to 'day': 'returning', 'timecode', 'severely', 'garner', 'coup', 'techniques',
# Nearest to 'one': 'six', 'two', 'seven', 'four', 'five', 'three',
# Nearest to 'up': 'them', 'him', 'out', 'thr', 'loup', 'sprawling',
# Nearest to 'for': 'in', 'cl', 'of', 'adiabatic', 'saguinus', 'and',
# Nearest to 'long': 'otimes', 'djamena', 'er', 'threats', 'michelob', 'toto',
# Nearest to 'power': 'dasyprocta', 'thief', 'ssbn', 'albuquerque', 'yin', 'trinomial',
# Nearest to 'second': 'apollonia', 'first', 'last', 'burnt', 'clay', 'imran',
# Nearest to 'state': 'gonna', 'laid', 'tamarin', 'victoriae', 'woods', 'dasyprocta',
# Nearest to 'are': 'were', 'is', 'have', 'aorta', 'michelob', 'be',
# Average loss at step 72000 is 4.802
# Average loss at step 74000 is 4.777
# Average loss at step 76000 is 4.872
# Average loss at step 78000 is 4.777
# Average loss at step 80000 is 4.826
# Nearest to 'john': 'UNK', 'charles', 'lara', 'gerson', 'monasticism', 'cegep',
# Nearest to 'a': 'the', 'annales', 'michelob', 'amalthea', 'bottles', 'incompressible',
# Nearest to 'they': 'he', 'we', 'there', 'you', 'it', 'not',
# Nearest to 'life': 'johansen', 'alejandro', 'slurs', 'novel', 'bakunin', 'hyper',
# Nearest to 'if': 'when', 'where', 'but', 'lemmy', 'michelob', 'thaler',
# Nearest to 'work': 'dasyprocta', 'upanija', 'trinomial', 'agouti', 'microcebus', 'intervened',
# Nearest to 'found': 'used', 'microsite', 'discarded', 'reginae', 'cc', 'dasyprocta',
# Nearest to 'an': 'filthy', 'the', 'equine', 'regarded', 'cdp', 'mirror',
# Nearest to 'only': 'agave', 'trinomial', 'agouti', 'especially', 'pontificia', 'usually',
# Nearest to 'time': 'adiabatic', 'agouti', 'examination', 'dissonant', 'sylia', 'recitative',
# Nearest to 'united': 'fusion', 'hephaestion', 'victoriae', 'upanija', 'northern', 'butcher',
# Nearest to 'UNK': 'callithrix', 'microcebus', 'cegep', 'abet', 'wct', 'seven',
# Nearest to 'b': 'd', 'UNK', 'abet', 'p', 'callithrix', 'wct',
# Nearest to 'its': 'their', 'his', 'the', 'her', 'permeable', 'dasyprocta',
# Nearest to 'against': 'during', 'punishments', 'tillich', 'including', 'for', 'landmasses',
# Nearest to 'but': 'however', 'and', 'callithrix', 'michelob', 'dasyprocta', 'tamarin',
# Nearest to 'be': 'been', 'have', 'is', 'was', 'were', 'become',
# Nearest to 'by': 'was', 'michelob', 'from', 'with', 'iit', 'be',
# Nearest to 'system': 'staff', 'mutual', 'confirm', 'teleprinter', 'cebus', 'logic',
# Nearest to 'at': 'in', 'cegep', 'on', 'from', 'agave', 'aquila',
# Nearest to 'history': 'rudolph', 'thaler', 'dasyprocta', 'tamarin', 'fishing', 'founding',
# Nearest to 'm': 'UNK', 'seven', 'hydrochloric', 'shipper', 'gb', 'three',
# Nearest to 'three': 'six', 'four', 'five', 'seven', 'two', 'eight',
# Nearest to 'day': 'candide', 'returning', 'severely', 'timecode', 'coup', 'techniques',
# Nearest to 'one': 'six', 'two', 'three', 'seven', 'four', 'five',
# Nearest to 'up': 'them', 'him', 'out', 'thr', 'standardised', 'sprawling',
# Nearest to 'for': 'cl', 'in', 'agave', 'adiabatic', 'cebus', 'or',
# Nearest to 'long': 'djamena', 'otimes', 'er', 'excelled', 'toto', 'apr',
# Nearest to 'power': 'thief', 'dasyprocta', 'ssbn', 'albuquerque', 'yin', 'clips',
# Nearest to 'second': 'first', 'last', 'apollonia', 'klister', 'burnt', 'fastest',
# Nearest to 'state': 'gonna', 'tamarin', 'laid', 'victoriae', 'dasyprocta', 'agouti',
# Nearest to 'are': 'were', 'is', 'have', 'include', 'michelob', 'absinthe',
# Average loss at step 82000 is 4.812
# Average loss at step 84000 is 4.785
# Average loss at step 86000 is 4.805
# Average loss at step 88000 is 4.693
# Average loss at step 90000 is 4.767
# Nearest to 'john': 'UNK', 'charles', 'lara', 'monasticism', 'gerson', 'cegep',
# Nearest to 'a': 'the', 'amalthea', 'annales', 'michelob', 'any', 'reginae',
# Nearest to 'they': 'he', 'we', 'there', 'you', 'it', 'not',
# Nearest to 'life': 'johansen', 'alejandro', 'slurs', 'novel', 'callithrix', 'bakunin',
# Nearest to 'if': 'when', 'where', 'but', 'michelob', 'thaler', 'can',
# Nearest to 'work': 'dasyprocta', 'trinomial', 'upanija', 'microcebus', 'agouti', 'intervened',
# Nearest to 'found': 'used', 'microsite', 'discarded', 'reginae', 'cc', 'salinity',
# Nearest to 'an': 'filthy', 'equine', 'the', 'mirror', 'cdp', 'scheduled',
# Nearest to 'only': 'agave', 'agouti', 'thaler', 'pontificia', 'usually', 'trinomial',
# Nearest to 'time': 'adiabatic', 'agouti', 'examination', 'while', 'sylia', 'dissonant',
# Nearest to 'united': 'fusion', 'hephaestion', 'victoriae', 'northern', 'butcher', 'upanija',
# Nearest to 'UNK': 'abet', 'cegep', 'callithrix', 'microcebus', 'michelob', 'dasyprocta',
# Nearest to 'b': 'd', 'p', 'six', 'abet', 'callithrix', 'four',
# Nearest to 'its': 'their', 'his', 'the', 'her', 'permeable', 'dasyprocta',
# Nearest to 'against': 'during', 'punishments', 'tillich', 'including', 'arctos', 'for',
# Nearest to 'but': 'however', 'and', 'callithrix', 'or', 'dasyprocta', 'michelob',
# Nearest to 'be': 'been', 'have', 'become', 'is', 'was', 'were',
# Nearest to 'by': 'was', 'michelob', 'iit', 'from', 'be', 'with',
# Nearest to 'system': 'staff', 'callithrix', 'cebus', 'confirm', 'mutual', 'dasyprocta',
# Nearest to 'at': 'in', 'cegep', 'on', 'for', 'aquila', 'microcebus',
# Nearest to 'history': 'rudolph', 'thaler', 'dasyprocta', 'tamarin', 'fishing', 'plate',
# Nearest to 'm': 'gb', 'c', 'zero', 'shipper', 'hydrochloric', 'UNK',
# Nearest to 'three': 'four', 'two', 'five', 'six', 'seven', 'eight',
# Nearest to 'day': 'candide', 'returning', 'timecode', 'severely', 'coup', 'techniques',
# Nearest to 'one': 'seven', 'four', 'six', 'two', 'five', 'eight',
# Nearest to 'up': 'them', 'him', 'out', 'standardised', 'sprawling', 'thr',
# Nearest to 'for': 'cl', 'of', 'in', 'dasyprocta', 'saguinus', 'adiabatic',
# Nearest to 'long': 'djamena', 'otimes', 'er', 'apr', 'excelled', 'threats',
# Nearest to 'power': 'dasyprocta', 'thief', 'ssbn', 'albuquerque', 'cyp', 'yin',
# Nearest to 'second': 'first', 'last', 'apollonia', 'klister', 'ammonite', 'fastest',
# Nearest to 'state': 'gonna', 'office', 'laid', 'victoriae', 'tamarin', 'asymptotic',
# Nearest to 'are': 'were', 'is', 'have', 'include', 'michelob', 'be',
# Average loss at step 92000 is 4.719
# Average loss at step 94000 is 4.625
# Average loss at step 96000 is 4.728
# Average loss at step 98000 is 4.631
# Average loss at step 100000 is 4.670
# Nearest to 'john': 'charles', 'UNK', 'gerson', 'polite', 'donatello', 'monasticism',
# Nearest to 'a': 'the', 'any', 'amalthea', 'michelob', 'annales', 'bottles',
# Nearest to 'they': 'we', 'he', 'there', 'you', 'it', 'not',
# Nearest to 'life': 'johansen', 'alejandro', 'novel', 'slurs', 'career', 'callithrix',
# Nearest to 'if': 'when', 'where', 'while', 'is', 'but', 'although',
# Nearest to 'work': 'dasyprocta', 'trinomial', 'upanija', 'microcebus', 'agouti', 'intervened',
# Nearest to 'found': 'used', 'reginae', 'discarded', 'microsite', 'cc', 'built',
# Nearest to 'an': 'the', 'filthy', 'equine', 'mirror', 'scheduled', 'normandy',
# Nearest to 'only': 'agave', 'especially', 'usually', 'agouti', 'pontificia', 'thaler',
# Nearest to 'time': 'adiabatic', 'agouti', 'sylia', 'dissonant', 'movies', 'examination',
# Nearest to 'united': 'fusion', 'northern', 'hephaestion', 'butcher', 'victoriae', 'upanija',
# Nearest to 'UNK': 'cegep', 'microcebus', 'wct', 'abet', 'callithrix', 'victoriae',
# Nearest to 'b': 'd', 'abet', 'p', 'wct', 'callithrix', 'clodius',
# Nearest to 'its': 'their', 'his', 'the', 'her', 'permeable', 'dasyprocta',
# Nearest to 'against': 'during', 'including', 'punishments', 'tillich', 'arctos', 'from',
# Nearest to 'but': 'and', 'however', 'although', 'while', 'or', 'callithrix',
# Nearest to 'be': 'been', 'have', 'become', 'by', 'was', 'were',
# Nearest to 'by': 'michelob', 'be', 'was', 'iit', 'mal', 'through',
# Nearest to 'system': 'systems', 'staff', 'confirm', 'mutual', 'callithrix', 'teleprinter',
# Nearest to 'at': 'in', 'cegep', 'on', 'from', 'fabric', 'aquila',
# Nearest to 'history': 'rudolph', 'dasyprocta', 'thaler', 'tamarin', 'founding', 'fishing',
# Nearest to 'm': 'four', 'three', 'five', 'six', 'UNK', 'c',
# Nearest to 'three': 'four', 'five', 'six', 'seven', 'two', 'eight',
# Nearest to 'day': 'candide', 'returning', 'severely', 'timecode', 'techniques', 'coup',
# Nearest to 'one': 'two', 'six', 'seven', 'four', 'five', 'three',
# Nearest to 'up': 'him', 'them', 'out', 'off', 'sprawling', 'theists',
# Nearest to 'for': 'cl', 'in', 'or', 'dasyprocta', 'and', 'upanija',
# Nearest to 'long': 'djamena', 'er', 'otimes', 'apr', 'toto', 'excelled',
# Nearest to 'power': 'thief', 'dasyprocta', 'albuquerque', 'cyp', 'ssbn', 'summoned',
# Nearest to 'second': 'first', 'last', 'apollonia', 'third', 'burnt', 'klister',
# Nearest to 'state': 'gonna', 'tamarin', 'victoriae', 'office', 'asymptotic', 'aquila',
# Nearest to 'are': 'were', 'have', 'is', 'be', 'include', 'michelob',

# %% [markdown]
# # 5. Visualize the embeding

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
    plt.show()
    
# Plot
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
