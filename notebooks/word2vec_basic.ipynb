# %%
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1. Download the text and make corpus (set of words)

# %%
# Download (or reuse) the text file that we will use 
folder_dir  = "data"
file_name   = "text8.zip"
file_path   = os.path.join(folder_dir, file_name)
url         = 'http://mattmahoney.net/dc/'
if not os.path.exists(file_path):
    print ("No file found. Start downloading")
    downfilename, _ = urllib.request.urlretrieve(url + file_name, file_path)
    print ("'%s' downloaded" % (downfilename))
else:
    print ("File already exists") 

# Check we have correnct data 
statinfo = os.stat(file_path)
expected_bytes = 31344016
if statinfo.st_size == expected_bytes:
    print ("I guess we have correct file at '%s'" % (file_path))
else:
    print ("Something's wrong with the file at '%s'" % (file_path))

# Unzip the file
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = f.read(f.namelist()[0]).split()
    return data
words = read_data(file_path) 

print ("Type of 'words' is %s / Length is %d " % (type(words), len(words)))
print ("'words' look like \n %s" %(words[0:10]))
# Out:
# File already exists
# I guess we have correct file at 'data/text8.zip'
# Type of 'words' is <type 'list'> / Length is 17005207
# 'words' look like
#  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# # 2. Make a dictionary with fixed length (using UNK token)

# %%
# Count the words 
vocabulary_size = 50000 
count = [['UNK', -1]] 
count.extend(collections.Counter(words).most_common(vocabulary_size - 1)) # -1 is for UNK 
print ("Type of 'count' is %s / Length is %d " % (type(count), len(count)))
print ("'count' looks like \n %s" % (count[0:10]))

# Make a dictionary
dictionary = dict() 
for word, _ in count:
    dictionary[word] = len(dictionary)
print ("\nType of 'dictionary' is %s / Length is %d " % (type(dictionary), len(dictionary))) 

# Make data using the dictionary 
data = list()
unk_count = 0
for word in words:
    if word in dictionary:
        index = dictionary[word]
    else:
        index = 0  # dictionary['UNK']
        unk_count += 1
    data.append(index)
count[0][1] = unk_count
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
print ("\nType of 'reverse_dictionary' is %s / Length is %d " 
       % (type(reverse_dictionary), len(reverse_dictionary))) 

# del words  # Hint to reduce memory.
# Out:
# Type of 'count' is <type 'list'> / Length is 50000
# 'count' looks like
#  [['UNK', -1], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
#
# Type of 'dictionary' is <type 'dict'> / Length is 50000
#
# Type of 'reverse_dictionary' is <type 'dict'> / Length is 50000

# %% [markdown]
# ### 'dictionary' converts word to index
# ### 'reverse_dictionary' converts index to word

# %%
print ("Most common words (+UNK) are \n %s" % (count[:5]))
print ("\nSample data \n %s" % (data[:10])) 
print ("\n Sample data corresponds to\n__________________")
for i in range(10):
    print ("%d->%s" % (data[i], reverse_dictionary[data[i]]))
# Out:
# Most common words (+UNK) are
#  [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
#
# Sample data
#  [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
#
#  Sample data corresponds to
# __________________
# 5239->anarchism
# 3084->originated
# 12->as
# 6->a
# 195->term
# 2->of
# 3137->abuse
# 46->first
# 59->used
# 156->against

# %% [markdown]
# # Batch-generating function for skip-gram model
# ## - Skip-gram (one word to one word) => Can generate more training data
#
# <img src="images/etc/word2vec_desc.png">

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch  = np.ndarray(shape=(batch_size),    dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips): # '//' makes the result an integer, e.g., 7//3 = 2
        target = skip_window
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %% [markdown]
# ### Examples for generating batch and labels

# %%
data_index = 0
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1) # num_skips=2, skip_window=1
print ("Type of 'batch' is %s / Length is %d " 
       % (type(batch), len(batch))) 
print ("Type of 'labels' is %s / Length is %d " 
       % (type(labels), len(labels))) 

print ("\n'batch' looks like \n %s" % (batch))
print ("\n'labels' looks like \n %s" % (labels)) 

for i in range(8):
    print ("%d -> %d" % (batch[i], labels[i, 0])),
    print ("\t%s -> %s" % (reverse_dictionary[batch[i]], reverse_dictionary[labels[i, 0]])) 
    
print ("'words' look like \n %s" %(words[0:10]))
# Out:
# Type of 'batch' is <type 'numpy.ndarray'> / Length is 8
# Type of 'labels' is <type 'numpy.ndarray'> / Length is 8
#
# 'batch' looks like
#  [3084 3084   12   12    6    6  195  195]
#
# 'labels' looks like
#  [[  12]
#  [5239]
#  [   6]
#  [3084]
#  [ 195]
#  [  12]
#  [   6]
#  [   2]]
# 3084 -> 12 	originated -> as
# 3084 -> 5239 	originated -> anarchism
# 12 -> 6 	as -> a
# 12 -> 3084 	as -> originated
# 6 -> 195 	a -> term
# 6 -> 12 	a -> as
# 195 -> 6 	term -> a
# 195 -> 2 	term -> of
# 'words' look like
#  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# # 3. Build a Skip-Gram Model

# %%
batch_size     = 128
embedding_size = 128       # Dimension of the embedding vector.
skip_window    = 1         # How many words to consider left and right.
num_skips      = 2         # How many times to reuse an input to generate a label.

# Random validation set to sample nearest neighbors.
# this is negative sample  
valid_size     = 16        # Random set of words to evaluate similarity on.
valid_window   = 100       # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


# Construct the word2vec model 
train_inputs   = tf.placeholder(tf.int32, shape=[batch_size])    # This is index 
train_labels   = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset  = tf.constant(valid_examples, dtype=tf.int32)

# Look up embeddings for inputs. (vocabulary_size = 50,000)
with tf.variable_scope("EMBEDDING"):
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
    
# Construct the variables for the NCE loss
with tf.variable_scope("NCE_WEIGHT"):
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
# Loss function 
# tf.nce_loss automatically draws a new sample of negative labels (=num_sampled)
num_sampled = 64        # Number of negative examples to sample. 
loss = tf.reduce_mean(
    tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels, num_sampled, vocabulary_size))
# Optimizer
optm = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
# Similarity measure (important)
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
siml = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
    
print ("Network Ready")
# Out:
# Network Ready

# %% [markdown]
# # 4. Train a Skip-Gram Model

# %%
# Train! 
sess = tf.Session()
sess.run(tf.initialize_all_variables())
summary_writer = tf.train.SummaryWriter('/tmp/tf_logs/word2vec', graph=sess.graph)
average_loss = 0

num_steps = 100001
for iter in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}
    _, loss_val = sess.run([optm, loss], feed_dict=feed_dict)
    average_loss += loss_val
    
    if iter % 2000 == 0:
        average_loss /= 2000
        print ("\nAverage loss at step %d is %.3f" % (iter, average_loss)) 
    
    if iter % 10000 == 0:
        siml_val = sess.run(siml)
        for i in xrange(valid_size): # Among valid set 
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-siml_val[i, :]).argsort()[1:top_k+1]
            log_str = "Nearest to '%s':" % valid_word
            for k in xrange(top_k):
                close_word = reverse_dictionary[nearest[k]] 
                log_str = "%s '%s'," % (log_str, close_word)
            print(log_str) 
            
# Final embeding 
final_embeddings = sess.run(normalized_embeddings)
# Out:
# Average loss at step 0 is 0.141
# Nearest to 'had': 'ecole', 'misogyny', 'eamonn', 'songhai', 'distinction', 'gojira', 'emery', 'environmental',
# Nearest to 'his': 'calculus', 'striking', 'string', 'wikibook', 'intercepted', 'ordination', 'credo', 'abandons',
# Nearest to 'he': 'warez', 'alexandrina', 'spink', 'nene', 'sadr', 'germaine', 'py', 'sparking',
# Nearest to 'world': 'fetus', 'vee', 'scouts', 'gch', 'protecting', 'fake', 'reactant', 'height',
# Nearest to 'between': 'sargent', 'harrow', 'triple', 'alkoxide', 'curbed', 'xv', 'conifer', 'processors',
# Nearest to 'as': 'privatized', 'wise', 'feininger', 'tuareg', 'dissension', 'benedict', 'quarks', 'mayonnaise',
# Nearest to 'during': 'decentralization', 'antibodies', 'legitimately', 'retraction', 'pumpkins', 'dubrovnik', 'mcmillan', 'macaroni',
# Nearest to 's': 'dungeons', 'revoluci', 'webber', 'possessed', 'montferrat', 'amundsen', 'noxious', 'mistresses',
# Nearest to 'd': 'denethor', 'amphitheatre', 'slots', 'lutheran', 'ariel', 'baryon', 'mckenzie', 'psalm',
# Nearest to 'about': 'seafood', 'heaney', 'analgesia', 'insights', 'terri', 'gershwin', 'dat', 'eyepiece',
# Nearest to 'which': 'varanus', 'imr', 'inscription', 'foresee', 'janos', 'transactional', 'welcoming', 'aboriginal',
# Nearest to 'or': 'enjoyment', 'expatriate', 'aesop', 'analytical', 'bullseye', 'chloroplasts', 'poem', 'eratosthenes',
# Nearest to 'if': 'morales', 'specificity', 'phenomenon', 'birthdays', 'tastes', 'ailes', 'maryam', 'thuringiensis',
# Nearest to 'two': 'unopened', 'industry', 'hyderabad', 'patriotism', 'goddard', 'aged', 'rnsson', 'wavefunctions',
# Nearest to 'has': 'charenton', 'radiohead', 'viridian', 'grazed', 'vie', 'poole', 'separatists', 'adolphus',
# Nearest to 'may': 'foremost', 'ramparts', 'libyan', 'nutmeg', 'nabokov', 'arriving', 'bung', 'mandates',
#
# Average loss at step 2000 is 114.094
#
# Average loss at step 4000 is 52.899
#
# Average loss at step 6000 is 33.564
#
# Average loss at step 8000 is 23.334
#
# Average loss at step 10000 is 17.487
# Nearest to 'had': 'adapted', 'shared', 'victoriae', 'distinction', 'blockade', 'henry', 'were', 'combustion',
# Nearest to 'his': 'the', 'striking', 'calculus', 'algae', 'yard', 'ban', 'phi', 'two',
# Nearest to 'he': 'phi', 'victoriae', 'it', 'ada', 'sadr', 'simone', 'india', 'and',
# Nearest to 'world': 'fetus', 'passes', 'keeps', 'gch', 'height', 'universally', 'protecting', 'vee',
# Nearest to 'between': 'processors', 'triple', 'gases', 'railways', 'penguin', 'nasa', 'citadel', 'and',
# Nearest to 'as': 'in', 'vila', 'is', 'phi', 'behaviours', 'and', 'quarks', 'schemata',
# Nearest to 'during': 'mathbf', 'austin', 'italian', 'captured', 'rationals', 'var', 'cask', 'admitted',
# Nearest to 's': 'and', 'eichmann', 'of', 'alpina', 'relativity', 'the', 'massive', 'possessed',
# Nearest to 'd': 'nine', 'lutheran', 'domain', 'victoriae', 'gb', 'wikibooks', 'discovery', 'scrimmage',
# Nearest to 'about': 'victoriae', 'in', 'tradition', 'seafood', 'economics', 'vila', 'gershwin', 'hundred',
# Nearest to 'which': 'and', 'phi', 'performed', 'welcoming', 'potato', 'alpina', 'europe', 'when',
# Nearest to 'or': 'and', 'analytical', 'victoriae', 'UNK', 'thoughts', 'physicist', 'is', 'ensure',
# Nearest to 'if': 'phenomenon', 'ep', 'sleeping', 'computer', 'moderate', 'sub', 'refer', 'heads',
# Nearest to 'two': 'one', 'victoriae', 'nine', 'phi', 'reginae', 'tubing', 'gland', 'density',
# Nearest to 'has': 'is', 'was', 'clockwork', 'radiohead', 'victoriae', 'contemporary', 'inversion', 'had',
# Nearest to 'may': 'are', 'foremost', 'fragment', 'staging', 'unless', 'exists', 'site', 'geoffrey',
#
# Average loss at step 12000 is 14.156
#
# Average loss at step 14000 is 11.501
#
# Average loss at step 16000 is 9.861
#
# Average loss at step 18000 is 8.606
#
# Average loss at step 20000 is 7.761
# Nearest to 'had': 'has', 'was', 'were', 'have', 'adapted', 'and', 'victoriae', 'shared',
# Nearest to 'his': 'the', 'its', 'their', 's', 'caiman', 'a', 'subkey', 'phi',
# Nearest to 'he': 'it', 'they', 'and', 'phi', 'victoriae', 'hath', 'agouti', 'texts',
# Nearest to 'world': 'fetus', 'passes', 'keeps', 'height', 'protecting', 'gch', 'universally', 'vee',
# Nearest to 'between': 'sargent', 'triple', 'gases', 'processors', 'on', 'railways', 'in', 'conifer',
# Nearest to 'as': 'and', 'vila', 'in', 'is', 'by', 'phi', 'behaviours', 'clem',
# Nearest to 'during': 'in', 'by', 'and', 'mathbf', 'legitimately', 'antibodies', 'statesman', 'italian',
# Nearest to 's': 'and', 'zero', 'the', 'his', 'of', 'alpina', 'anacharsis', 'sunda',
# Nearest to 'd': 'b', 'domain', 'lutheran', 'positive', 'agouti', 'and', 'amino', 'gb',
# Nearest to 'about': 'victoriae', 'tradition', 'seafood', 'nine', 'kinsman', 'in', 'four', 'eight',
# Nearest to 'which': 'and', 'that', 'it', 'this', 'UNK', 'phi', 'also', 'welcoming',
# Nearest to 'or': 'and', 'victoriae', 'cc', 'six', 'analytical', 'was', 'eight', 'abductions',
# Nearest to 'if': 'when', 'phenomenon', 'ep', 'claudian', 'wendish', 'is', 'computer', 'canonical',
# Nearest to 'two': 'one', 'three', 'six', 'eight', 'four', 'seven', 'zero', 'five',
# Nearest to 'has': 'is', 'had', 'was', 'have', 'in', 'clockwork', 'discharged', 'inversion',
# Nearest to 'may': 'are', 'unless', 'assemblies', 'eight', 'geoffrey', 'should', 'exists', 'dumped',
#
# Average loss at step 22000 is 7.258
#
# Average loss at step 24000 is 6.962
#
# Average loss at step 26000 is 6.737
#
# Average loss at step 28000 is 6.249
#
# Average loss at step 30000 is 6.197
# Nearest to 'had': 'has', 'have', 'was', 'were', 'is', 'adapted', 'victoriae', 'shared',
# Nearest to 'his': 'the', 'their', 'its', 's', 'her', 'a', 'airshow', 'striking',
# Nearest to 'he': 'it', 'they', 'she', 'who', 'akita', 'phi', 'hath', 'and',
# Nearest to 'world': 'fetus', 'trinomial', 'passes', 'keeps', 'protecting', 'height', 'abakan', 'gch',
# Nearest to 'between': 'triple', 'sargent', 'gases', 'on', 'in', 'railways', 'processors', 'of',
# Nearest to 'as': 'trinomial', 'vila', 'in', 'by', 'is', 'and', 'phi', 'with',
# Nearest to 'during': 'in', 'by', 'legitimately', 'antibodies', 'from', 'tabled', 'statesman', 'mathbf',
# Nearest to 's': 'and', 'the', 'his', 'aorta', 'zero', 'of', 'or', 'five',
# Nearest to 'd': 'b', 'ariel', 'talmudic', 'domain', 'agouti', 'harold', 'gb', 'francesco',
# Nearest to 'about': 'in', 'victoriae', 'seafood', 'tradition', 'four', 'kinsman', 'lpc', 'aba',
# Nearest to 'which': 'that', 'this', 'it', 'otimes', 'and', 'also', 'amalthea', 'mishnayot',
# Nearest to 'or': 'and', 'victoriae', 'cc', 'primigenius', 'agouti', 'lpc', 'eight', 'aorta',
# Nearest to 'if': 'when', 'is', 'phenomenon', 'claudian', 'wendish', 'in', 'ep', 'canonical',
# Nearest to 'two': 'three', 'four', 'one', 'six', 'five', 'eight', 'seven', 'nine',
# Nearest to 'has': 'had', 'is', 'was', 'have', 'in', 'discharged', 'inversion', 'camel',
# Nearest to 'may': 'should', 'would', 'can', 'unless', 'are', 'assemblies', 'will', 'exists',
#
# Average loss at step 32000 is 5.903
#
# Average loss at step 34000 is 5.885
#
# Average loss at step 36000 is 5.737
#
# Average loss at step 38000 is 5.261
#
# Average loss at step 40000 is 5.469
# Nearest to 'had': 'has', 'have', 'was', 'were', 'grips', 'is', 'adapted', 'cassation',
# Nearest to 'his': 'their', 'the', 'its', 'her', 's', 'guderian', 'a', 'caiman',
# Nearest to 'he': 'it', 'they', 'she', 'who', 'phi', 'akita', 'victoriae', 'there',
# Nearest to 'world': 'fetus', 'trinomial', 'passes', 'height', 'keeps', 'protecting', 'abakan', 'gch',
# Nearest to 'between': 'triple', 'in', 'sargent', 'on', 'railways', 'with', 'gases', 'six',
# Nearest to 'as': 'vila', 'trinomial', 'by', 'phi', 'austin', 'in', 'reginae', 'is',
# Nearest to 'during': 'in', 'from', 'through', 'legitimately', 'antibodies', 'tabled', 'bsd', 'superseded',
# Nearest to 's': 'and', 'his', 'aorta', 'sunda', 'modular', 'anacharsis', 'was', 'cheese',
# Nearest to 'd': 'b', 'UNK', 'and', 'ifad', 'talmudic', 'harold', 'ariel', 'amphitheatre',
# Nearest to 'about': 'seafood', 'victoriae', 'pickups', 'tradition', 'in', 'four', 'kinsman', 'lpc',
# Nearest to 'which': 'that', 'this', 'it', 'and', 'also', 'otimes', 'one', 'amalthea',
# Nearest to 'or': 'and', 'victoriae', 'eight', 'cc', 'three', 'than', 'four', 'seven',
# Nearest to 'if': 'when', 'is', 'morales', 'in', 'claudian', 'phenomenon', 'wendish', 'corrupts',
# Nearest to 'two': 'three', 'four', 'six', 'one', 'five', 'seven', 'eight', 'zero',
# Nearest to 'has': 'had', 'is', 'was', 'have', 'viridian', 'in', 'discharged', 'victoriae',
# Nearest to 'may': 'can', 'should', 'would', 'will', 'unless', 'assemblies', 'could', 'dumped',
#
# Average loss at step 42000 is 5.350
#
# Average loss at step 44000 is 5.281
#
# Average loss at step 46000 is 5.284
#
# Average loss at step 48000 is 5.042
#
# Average loss at step 50000 is 5.156
# Nearest to 'had': 'has', 'have', 'was', 'were', 'grips', 'is', 'adapted', 'eight',
# Nearest to 'his': 'their', 'its', 'her', 'the', 's', 'guderian', 'reginae', 'caiman',
# Nearest to 'he': 'it', 'they', 'she', 'who', 'there', 'akita', 'condensates', 'this',
# Nearest to 'world': 'fetus', 'trinomial', 'passes', 'abakan', 'keeps', 'protecting', 'height', 'history',
# Nearest to 'between': 'triple', 'with', 'on', 'in', 'railways', 'sargent', 'when', 'following',
# Nearest to 'as': 'vila', 'trinomial', 'eight', 'reginae', 'austin', 'behaviours', 'by', 'thibetanus',
# Nearest to 'during': 'in', 'from', 'through', 'legitimately', 'when', 'antibodies', 'tabled', 'superseded',
# Nearest to 's': 'and', 'his', 'aorta', 'zero', 'eight', 'five', 'anacharsis', 'quad',
# Nearest to 'd': 'b', 'talmudic', 'ifad', 'francesco', 'harold', 'ariel', 'amphitheatre', 'advancing',
# Nearest to 'about': 'victoriae', 'seafood', 'pickups', 'in', 'aba', 'kinsman', 'four', 'tradition',
# Nearest to 'which': 'that', 'this', 'it', 'also', 'and', 'otimes', 'mishnayot', 'but',
# Nearest to 'or': 'and', 'eight', 'thibetanus', 'victoriae', 'than', 'cc', 'seven', 'primigenius',
# Nearest to 'if': 'when', 'tabula', 'is', 'morales', 'prism', 'claudian', 'corrupts', 'in',
# Nearest to 'two': 'three', 'four', 'one', 'six', 'five', 'seven', 'eight', 'thibetanus',
# Nearest to 'has': 'had', 'is', 'was', 'have', 'viridian', 'in', 'discharged', 'victoriae',
# Nearest to 'may': 'can', 'would', 'should', 'will', 'sotho', 'could', 'unless', 'eight',
#
# Average loss at step 52000 is 5.158
#
# Average loss at step 54000 is 5.099
#
# Average loss at step 56000 is 5.057
#
# Average loss at step 58000 is 5.099
#
# Average loss at step 60000 is 4.975
# Nearest to 'had': 'has', 'have', 'was', 'were', 'grips', 'is', 'cebus', 'adapted',
# Nearest to 'his': 'their', 'its', 'her', 'the', 's', 'cebus', 'callithrix', 'guderian',
# Nearest to 'he': 'it', 'she', 'they', 'who', 'there', 'akita', 'hath', 'phi',
# Nearest to 'world': 'fetus', 'trinomial', 'history', 'passes', 'abakan', 'keeps', 'protecting', 'height',
# Nearest to 'between': 'in', 'with', 'triple', 'tamarin', 'on', 'railways', 'following', 'callithrix',
# Nearest to 'as': 'tamarin', 'vila', 'callithrix', 'trinomial', 'reginae', 'austin', 'michelob', 'behaviours',
# Nearest to 'during': 'in', 'through', 'from', 'when', 'legitimately', 'at', 'against', 'antibodies',
# Nearest to 's': 'and', 'his', 'zero', 'aorta', 'callithrix', 'agouti', 'placebo', 'tamarin',
# Nearest to 'd': 'b', 'francesco', 'ifad', 'talmudic', 'amphitheatre', 'agouti', 'harold', 'ariel',
# Nearest to 'about': 'victoriae', 'pickups', 'seafood', 'five', 'kinsman', 'in', 'misdiagnosed', 'callithrix',
# Nearest to 'which': 'that', 'this', 'it', 'also', 'callithrix', 'otimes', 'but', 'one',
# Nearest to 'or': 'and', 'marmoset', 'thibetanus', 'callithrix', 'victoriae', 'eight', 'cc', 'but',
# Nearest to 'if': 'when', 'callithrix', 'is', 'tabula', 'should', 'corrupts', 'prism', 'morales',
# Nearest to 'two': 'three', 'four', 'five', 'six', 'one', 'seven', 'eight', 'microcebus',
# Nearest to 'has': 'had', 'have', 'was', 'is', 'viridian', 'discharged', 'agouti', 'victoriae',
# Nearest to 'may': 'can', 'would', 'should', 'will', 'could', 'sotho', 'unless', 'michelob',
#
# Average loss at step 62000 is 4.798
#
# Average loss at step 64000 is 4.796
#
# Average loss at step 66000 is 5.000
#
# Average loss at step 68000 is 4.910
#
# Average loss at step 70000 is 4.774
# Nearest to 'had': 'has', 'have', 'was', 'were', 'thaler', 'grips', 'since', 'is',
# Nearest to 'his': 'their', 'its', 'her', 'the', 'cebus', 's', 'callithrix', 'bracing',
# Nearest to 'he': 'it', 'she', 'they', 'who', 'there', 'condensates', 'akita', 'hath',
# Nearest to 'world': 'fetus', 'trinomial', 'passes', 'keeps', 'abakan', 'history', 'protecting', 'height',
# Nearest to 'between': 'with', 'in', 'tamarin', 'triple', 'following', 'railways', 'upanija', 'jaws',
# Nearest to 'as': 'tamarin', 'vila', 'trinomial', 'upanija', 'reginae', 'austin', 'callithrix', 'thaler',
# Nearest to 'during': 'in', 'from', 'through', 'when', 'after', 'following', 'callithrix', 'legitimately',
# Nearest to 's': 'and', 'upanija', 'bracing', 'his', 'callithrix', 'aorta', 'zero', 'agouti',
# Nearest to 'd': 'b', 'ifad', 'francesco', 'amphitheatre', 'talmudic', 'UNK', 'mitral', 'ariel',
# Nearest to 'about': 'six', 'victoriae', 'five', 'four', 'pickups', 'seafood', 'misdiagnosed', 'three',
# Nearest to 'which': 'that', 'this', 'it', 'also', 'but', 'and', 'callithrix', 'otimes',
# Nearest to 'or': 'and', 'marmoset', 'callithrix', 'thaler', 'thibetanus', 'tamarin', 'agouti', 'victoriae',
# Nearest to 'if': 'when', 'callithrix', 'is', 'in', 'tabula', 'corrupts', 'although', 'thaler',
# Nearest to 'two': 'three', 'four', 'six', 'five', 'one', 'seven', 'eight', 'microcebus',
# Nearest to 'has': 'had', 'have', 'is', 'was', 'thaler', 'in', 'since', 'agouti',
# Nearest to 'may': 'can', 'would', 'will', 'should', 'could', 'ero', 'sotho', 'might',
#
# Average loss at step 72000 is 4.796
#
# Average loss at step 74000 is 4.764
#
# Average loss at step 76000 is 4.887
#
# Average loss at step 78000 is 4.808
#
# Average loss at step 80000 is 4.820
# Nearest to 'had': 'has', 'have', 'was', 'were', 'grips', 'since', 'thaler', 'pontificia',
# Nearest to 'his': 'their', 'its', 'her', 'the', 's', 'cebus', 'bracing', 'guderian',
# Nearest to 'he': 'it', 'she', 'they', 'who', 'there', 'phi', 'akita', 'condensates',
# Nearest to 'world': 'fetus', 'trinomial', 'abakan', 'passes', 'keeps', 'protecting', 'height', 'history',
# Nearest to 'between': 'with', 'in', 'tamarin', 'triple', 'cofinality', 'following', 'from', 'railways',
# Nearest to 'as': 'tamarin', 'vila', 'upanija', 'trinomial', 'austin', 'reginae', 'behaviours', 'vec',
# Nearest to 'during': 'in', 'through', 'from', 'when', 'after', 'following', 'callithrix', 'legitimately',
# Nearest to 's': 'upanija', 'aorta', 'placebo', 'bracing', 'his', 'vec', 'agouti', 'zero',
# Nearest to 'd': 'b', 'UNK', 'shula', 'vec', 'talmudic', 'francesco', 'ifad', 'amphitheatre',
# Nearest to 'about': 'four', 'misdiagnosed', 'victoriae', 'pickups', 'embouchure', 'seafood', 'over', 'six',
# Nearest to 'which': 'this', 'that', 'it', 'also', 'vec', 'but', 'callithrix', 'and',
# Nearest to 'or': 'and', 'vec', 'marmoset', 'agouti', 'thibetanus', 'cegep', 'tamarin', 'callithrix',
# Nearest to 'if': 'when', 'callithrix', 'tabula', 'although', 'corrupts', 'thaler', 'vec', 'thibetanus',
# Nearest to 'two': 'three', 'four', 'six', 'five', 'seven', 'one', 'microcebus', 'eight',
# Nearest to 'has': 'had', 'have', 'is', 'was', 'since', 'thaler', 'in', 'agouti',
# Nearest to 'may': 'can', 'would', 'will', 'should', 'could', 'ero', 'might', 'sotho',
#
# Average loss at step 82000 is 4.819
#
# Average loss at step 84000 is 4.784
#
# Average loss at step 86000 is 4.759
#
# Average loss at step 88000 is 4.710
#
# Average loss at step 90000 is 4.775
# Nearest to 'had': 'has', 'have', 'was', 'were', 'since', 'grips', 'thaler', 'revive',
# Nearest to 'his': 'their', 'her', 'its', 'the', 's', 'callithrix', 'cebus', 'your',
# Nearest to 'he': 'it', 'she', 'they', 'who', 'there', 'condensates', 'akita', 'phi',
# Nearest to 'world': 'fetus', 'trinomial', 'abakan', 'keeps', 'protecting', 'passes', 'height', 'history',
# Nearest to 'between': 'with', 'tamarin', 'triple', 'following', 'in', 'cofinality', 'on', 'harrow',
# Nearest to 'as': 'tamarin', 'vila', 'austin', 'upanija', 'reginae', 'physik', 'vec', 'callithrix',
# Nearest to 'during': 'in', 'through', 'from', 'after', 'when', 'following', 'against', 'at',
# Nearest to 's': 'his', 'placebo', 'aorta', 'hiding', 'upanija', 'and', 'callithrix', 'lamm',
# Nearest to 'd': 'b', 'vec', 'shula', 'zero', 'six', 'UNK', 'gb', 'mitral',
# Nearest to 'about': 'misdiagnosed', 'pickups', 'embouchure', 'over', 'victoriae', 'seafood', 'callithrix', 'aba',
# Nearest to 'which': 'that', 'this', 'but', 'also', 'it', 'callithrix', 'and', 'upanija',
# Nearest to 'or': 'and', 'vec', 'marmoset', 'cegep', 'thibetanus', 'agouti', 'callithrix', 'but',
# Nearest to 'if': 'when', 'callithrix', 'although', 'tabula', 'thaler', 'summarized', 'though', 'is',
# Nearest to 'two': 'three', 'four', 'five', 'six', 'seven', 'one', 'eight', 'microcebus',
# Nearest to 'has': 'had', 'have', 'is', 'was', 'since', 'thaler', 'agouti', 'in',
# Nearest to 'may': 'can', 'would', 'should', 'will', 'could', 'might', 'must', 'ero',
#
# Average loss at step 92000 is 4.717
#
# Average loss at step 94000 is 4.623
#
# Average loss at step 96000 is 4.729
#
# Average loss at step 98000 is 4.625
#
# Average loss at step 100000 is 4.688
# Nearest to 'had': 'has', 'have', 'was', 'were', 'since', 'thaler', 'grips', 'pontificia',
# Nearest to 'his': 'their', 'her', 'its', 'the', 's', 'your', 'callithrix', 'bunge',
# Nearest to 'he': 'it', 'she', 'they', 'who', 'there', 'condensates', 'itself', 'later',
# Nearest to 'world': 'fetus', 'trinomial', 'abakan', 'keeps', 'passes', 'protecting', 'history', 'height',
# Nearest to 'between': 'with', 'triple', 'following', 'in', 'tamarin', 'on', 'cofinality', 'harrow',
# Nearest to 'as': 'tamarin', 'upanija', 'reginae', 'vila', 'austin', 'trinomial', 'thaler', 'callithrix',
# Nearest to 'during': 'in', 'through', 'after', 'from', 'when', 'following', 'at', 'against',
# Nearest to 's': 'his', 'hiding', 'upanija', 'placebo', 'aorta', 'lamm', 'agouti', 'callithrix',
# Nearest to 'd': 'b', 'vec', 'shula', 'ifad', 'lar', 'agouti', 'mitral', 'j',
# Nearest to 'about': 'misdiagnosed', 'embouchure', 'pickups', 'over', 'seafood', 'victoriae', 'three', 'four',
# Nearest to 'which': 'that', 'this', 'it', 'but', 'also', 'callithrix', 'what', 'one',
# Nearest to 'or': 'and', 'vec', 'than', 'marmoset', 'cegep', 'thibetanus', 'gaku', 'but',
# Nearest to 'if': 'when', 'though', 'although', 'where', 'callithrix', 'tabula', 'corrupts', 'summarized',
# Nearest to 'two': 'three', 'four', 'six', 'five', 'seven', 'one', 'eight', 'microcebus',
# Nearest to 'has': 'had', 'have', 'was', 'is', 'since', 'thaler', 'agouti', 'seemed',
# Nearest to 'may': 'can', 'would', 'will', 'should', 'could', 'must', 'might', 'ero',

# %% [markdown]
# # 5. Visualize the embeding

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
    plt.show()
    
# Plot
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
