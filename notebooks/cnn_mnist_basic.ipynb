# %%
"""
 Convolutional Neural Network (CNN) with MNIST
 @Sungjoon Choi (sungjoon.choi@cpslab.snu.ac.kr
 based on "https://github.com/aymericdamien/TensorFlow-Examples/"
"""
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
# %matplotlib inline

# %%
mnist = input_data.read_data_sets('data/', one_hot=True)
trainimg   = mnist.train.images
trainlabel = mnist.train.labels
testimg    = mnist.test.images
testlabel  = mnist.test.labels
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
# Define convolutional neural network architecture 

# Parameters
learning_rate   = 0.001
training_epochs = 100
batch_size      = 100
display_step    = 1

# Network
n_input  = 784
n_output = 10
with tf.device('/gpu:2'):
    weights  = {
        'wc1': tf.Variable(tf.random_normal([3, 3, 1, 64], stddev=0.1)),
        'wc2': tf.Variable(tf.random_normal([3, 3, 64, 128], stddev=0.1)),
        'wd1': tf.Variable(tf.random_normal([7*7*128, 1024], stddev=0.1)),
        'wd2': tf.Variable(tf.random_normal([1024, n_output], stddev=0.1))
    }
    biases   = {
        'bc1': tf.Variable(tf.random_normal([64], stddev=0.1)),
        'bc2': tf.Variable(tf.random_normal([128], stddev=0.1)),
        'bd1': tf.Variable(tf.random_normal([1024], stddev=0.1)),
        'bd2': tf.Variable(tf.random_normal([n_output], stddev=0.1))
    }
    def conv_basic(_input, _w, _b, _keepratio):
        # Input
        _input_r = tf.reshape(_input, shape=[-1, 28, 28, 1])
        # Conv1
        _conv1 = tf.nn.conv2d(_input_r, _w['wc1'], strides=[1, 1, 1, 1], padding='SAME')
        _conv1 = tf.nn.batch_normalization(_conv1, 0.001, 1.0, 0, 1, 0.0001)
        _conv1 = tf.nn.relu(tf.nn.bias_add(_conv1, _b['bc1']))
        _pool1 = tf.nn.max_pool(_conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        _pool_dr1 = tf.nn.dropout(_pool1, _keepratio)
        # Conv2
        _conv2 = tf.nn.conv2d(_pool_dr1, _w['wc2'], strides=[1, 1, 1, 1], padding='SAME')
        _conv2 = tf.nn.batch_normalization(_conv2, 0.001, 1.0, 0, 1, 0.0001)
        _conv2 = tf.nn.relu(tf.nn.bias_add(_conv2, _b['bc2']))
        _pool2 = tf.nn.max_pool(_conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        _pool_dr2 = tf.nn.dropout(_pool2, _keepratio)
        # Vectorize
        _dense1 = tf.reshape(_pool_dr2, [-1, _w['wd1'].get_shape().as_list()[0]])
        # Fc1
        _fc1 = tf.nn.relu(tf.add(tf.matmul(_dense1, _w['wd1']), _b['bd1']))
        _fc_dr1 = tf.nn.dropout(_fc1, _keepratio)
        # Fc2
        _out = tf.add(tf.matmul(_fc_dr1, _w['wd2']), _b['bd2'])
        # Return everything
        out = {
            'input_r': _input_r,
            'conv1': _conv1,
            'pool1': _pool1,
            'pool1_dr1': _pool_dr1,
            'conv2': _conv2,
            'pool2': _pool2,
            'pool_dr2': _pool_dr2,
            'dense1': _dense1,
            'fc1': _fc1,
            'fc_dr1': _fc_dr1,
            'out': _out
        }
        return out

    # tf Graph input
    x = tf.placeholder(tf.float32, [None, n_input])
    y = tf.placeholder(tf.float32, [None, n_output])
    keepratio = tf.placeholder(tf.float32)

    # Functions! 
    _pred = conv_basic(x, weights, biases, keepratio)['out']
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(_pred, y))
    optm = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
    _corr = tf.equal(tf.argmax(_pred,1), tf.argmax(y,1)) # Count corrects
    accr = tf.reduce_mean(tf.cast(_corr, tf.float32)) # Accuracy
    init = tf.initialize_all_variables()

# Saver 
save_step = 1;
saver = tf.train.Saver(max_to_keep=training_epochs) 

print ("Network Ready to Go!")
# Out:
# Network Ready to Go!

# %%
do_train = 1

# Do some optimizations
sess = tf.Session()
sess.run(init)

if do_train == 1:
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Fit training using batch data
            sess.run(optm, feed_dict={x: batch_xs, y: batch_ys, keepratio:0.7})
            # Compute average loss
            avg_cost += sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keepratio:1.})/total_batch

        # Display logs per epoch step
        if epoch % display_step == 0: 
            print ("Epoch: %03d/%03d cost: %.9f" % (epoch, training_epochs, avg_cost))
            train_acc = sess.run(accr, feed_dict={x: batch_xs, y: batch_ys, keepratio:1.})
            print (" Training accuracy: %.3f" % (train_acc))
            test_acc = sess.run(accr, feed_dict={x: testimg, y: testlabel, keepratio:1.})
            print (" Test accuracy: %.3f" % (test_acc))

        # Save Net
        if epoch % save_step == 0:
            saver.save(sess, "nets/cnn_basic.ckpt-" + str(epoch))

    print ("Optimization Finished.")
# Out:
# Epoch: 000/100 cost: 0.317963983
#  Training accuracy: 0.980
#  Test accuracy: 0.979
# Epoch: 001/100 cost: 0.049138199
#  Training accuracy: 1.000
#  Test accuracy: 0.988
# Epoch: 002/100 cost: 0.030748716
#  Training accuracy: 0.990
#  Test accuracy: 0.988
# Epoch: 003/100 cost: 0.023464642
#  Training accuracy: 1.000
#  Test accuracy: 0.990
# Epoch: 004/100 cost: 0.016969528
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 005/100 cost: 0.013521486
#  Training accuracy: 0.990
#  Test accuracy: 0.992
# Epoch: 006/100 cost: 0.011437905
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 007/100 cost: 0.009204081
#  Training accuracy: 0.990
#  Test accuracy: 0.992
# Epoch: 008/100 cost: 0.007714789
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 009/100 cost: 0.006281783
#  Training accuracy: 0.980
#  Test accuracy: 0.992
# Epoch: 010/100 cost: 0.005473050
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 011/100 cost: 0.004620765
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 012/100 cost: 0.003844352
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 013/100 cost: 0.003640684
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 014/100 cost: 0.003253224
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 015/100 cost: 0.002993146
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 016/100 cost: 0.002448225
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 017/100 cost: 0.001732611
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 018/100 cost: 0.001744996
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 019/100 cost: 0.001561733
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 020/100 cost: 0.001194611
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 021/100 cost: 0.000866844
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 022/100 cost: 0.001071072
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 023/100 cost: 0.000854188
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 024/100 cost: 0.000577242
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 025/100 cost: 0.000714487
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 026/100 cost: 0.000545236
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 027/100 cost: 0.000556886
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 028/100 cost: 0.000613636
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 029/100 cost: 0.000437279
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 030/100 cost: 0.000444570
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 031/100 cost: 0.000333959
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 032/100 cost: 0.000258017
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 033/100 cost: 0.000287596
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 034/100 cost: 0.000354593
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 035/100 cost: 0.000300815
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 036/100 cost: 0.000290043
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 037/100 cost: 0.000173298
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 038/100 cost: 0.000334675
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 039/100 cost: 0.000372615
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 040/100 cost: 0.000248539
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 041/100 cost: 0.000237681
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 042/100 cost: 0.000098128
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 043/100 cost: 0.000207880
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 044/100 cost: 0.000194980
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 045/100 cost: 0.000109472
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 046/100 cost: 0.000072535
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 047/100 cost: 0.000220219
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 048/100 cost: 0.000064737
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 049/100 cost: 0.000170643
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 050/100 cost: 0.000129981
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 051/100 cost: 0.000084596
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 052/100 cost: 0.000082471
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 053/100 cost: 0.000152638
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 054/100 cost: 0.000087179
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 055/100 cost: 0.000115949
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 056/100 cost: 0.000098979
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 057/100 cost: 0.000189399
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 058/100 cost: 0.000199186
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 059/100 cost: 0.000024620
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 060/100 cost: 0.000120632
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 061/100 cost: 0.000048446
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 062/100 cost: 0.000063903
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 063/100 cost: 0.000134409
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 064/100 cost: 0.000083965
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 065/100 cost: 0.000011597
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 066/100 cost: 0.000358544
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 067/100 cost: 0.000203931
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 068/100 cost: 0.000067123
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 069/100 cost: 0.000032998
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 070/100 cost: 0.000035879
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 071/100 cost: 0.000107068
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 072/100 cost: 0.000075117
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 073/100 cost: 0.000065465
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 074/100 cost: 0.000021151
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 075/100 cost: 0.000007372
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 076/100 cost: 0.000009812
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 077/100 cost: 0.000104305
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 078/100 cost: 0.000330017
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 079/100 cost: 0.000061197
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 080/100 cost: 0.000014255
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 081/100 cost: 0.000061332
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 082/100 cost: 0.000035066
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 083/100 cost: 0.000064155
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 084/100 cost: 0.000031453
#  Training accuracy: 1.000
#  Test accuracy: 0.992
# Epoch: 085/100 cost: 0.000004603
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 086/100 cost: 0.000001383
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 087/100 cost: 0.000048827
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 088/100 cost: 0.000160180
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 089/100 cost: 0.000067370
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 090/100 cost: 0.000065727
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 091/100 cost: 0.000027757
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 092/100 cost: 0.000007617
#  Training accuracy: 1.000
#  Test accuracy: 0.993
# Epoch: 093/100 cost: 0.000033619
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 094/100 cost: 0.000005967
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 095/100 cost: 0.000185210
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 096/100 cost: 0.000001873
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 097/100 cost: 0.000125004
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 098/100 cost: 0.000042005
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Epoch: 099/100 cost: 0.000007795
#  Training accuracy: 1.000
#  Test accuracy: 0.994
# Optimization Finished.

# %%
# Restore net
if do_train == 0:
    epoch = 4
    saver.restore(sess, "nets/cnn_basic.ckpt-" + str(epoch))

# %%
# Compute test accuracy
test_acc = sess.run(accr, feed_dict={x: testimg, y: testlabel, keepratio:1.})
print (" Test accuracy: %.3f" % (test_acc))
# Out:
#  Test accuracy: 0.994
