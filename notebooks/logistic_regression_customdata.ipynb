# %%
"""
 Logistic Regression with Custom Data
 @Sungjoon Choi (sungjoon.choi@cpslab.snu.ac.kr)
"""
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Load them!
cwd = os.getcwd()
loadpath = cwd + "/data/trainingset.npz"
l = np.load(loadpath)

# See what's in here
l.files

# Parse data
trainimg = l['trainimg']
trainlabel = l['trainlabel']
testimg = l['testimg']
testlabel = l['testlabel']
ntrain = trainimg.shape[0]
nclass = trainlabel.shape[1]
dim    = trainimg.shape[1]
ntest  = testimg.shape[0]

print ("%d train images loaded" % (ntrain))
print ("%d test images loaded" % (ntest))
print ("%d dimensional input" % (dim))
print ("%d classes" % (nclass))
# Out:
# 69 train images loaded
# 18 test images loaded
# 900 dimensional input
# 2 classes

# %%
# Parameters of Logistic Regression
learning_rate   = 0.001
training_epochs = 1000
batch_size      = 10
display_step    = 10

# Create Graph for Logistic Regression
x = tf.placeholder("float", [None, dim]) 
y = tf.placeholder("float", [None, nclass])  # None is for infinite or unspecified length
W = tf.Variable(tf.zeros([dim, nclass]))
b = tf.Variable(tf.zeros([nclass]))

# Activation, Cost, and Optimizing functions
_pred = tf.nn.softmax(tf.matmul(x, W) + b) # Softmax
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(_pred), reduction_indices=1)) # Cross entropy
# cost = tf.reduce_mean(tf.pow(activation-y, 2))
optm = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost) # Gradient Descent
_corr = tf.equal(tf.argmax(_pred, 1), tf.argmax(y, 1))    
accr = tf.reduce_mean(tf.cast(_corr, tf.float32))
init = tf.initialize_all_variables()

print ("Network Ready")
# Out:
# Network Ready

# %%
# Launch the graph
sess = tf.Session()
sess.run(init)

# Training cycle
for epoch in range(training_epochs):
    avg_cost = 0.
    num_batch = int(ntrain/batch_size)
    # Loop over all batches
    for i in range(num_batch): 
        randidx = np.random.randint(ntrain, size=batch_size)
        batch_xs = trainimg[randidx, :]
        batch_ys = trainlabel[randidx, :]                
        # Fit training using batch data
        sess.run(optm, feed_dict={x: batch_xs, y: batch_ys})
        # Compute average loss
        avg_cost += sess.run(cost, feed_dict={x: batch_xs, y: batch_ys})/num_batch

    # Display logs per epoch step
    if epoch % display_step == 0:
        print ("Epoch: %03d/%03d cost: %.9f" % (epoch, training_epochs, avg_cost))
        train_acc = sess.run(accr, feed_dict={x: batch_xs, y: batch_ys})
        print (" Training accuracy: %.3f" % (train_acc))
        test_acc = sess.run(accr, feed_dict={x: testimg, y: testlabel})
        print (" Test accuracy: %.3f" % (test_acc))

print ("Optimization Finished!")
# Out:
# Epoch: 000/1000 cost: 0.677713056
#  Training accuracy: 0.600
#  Test accuracy: 0.444
# Epoch: 010/1000 cost: 0.647019178
#  Training accuracy: 0.400
#  Test accuracy: 0.389
# Epoch: 020/1000 cost: 0.620272974
#  Training accuracy: 0.500
#  Test accuracy: 0.444
# Epoch: 030/1000 cost: 0.596143623
#  Training accuracy: 0.600
#  Test accuracy: 0.389
# Epoch: 040/1000 cost: 0.610756665
#  Training accuracy: 0.300
#  Test accuracy: 0.389
# Epoch: 050/1000 cost: 0.597485046
#  Training accuracy: 0.900
#  Test accuracy: 0.500
# Epoch: 060/1000 cost: 0.563908676
#  Training accuracy: 0.800
#  Test accuracy: 0.444
# Epoch: 070/1000 cost: 0.561829552
#  Training accuracy: 0.700
#  Test accuracy: 0.500
# Epoch: 080/1000 cost: 0.569923252
#  Training accuracy: 0.800
#  Test accuracy: 0.500
# Epoch: 090/1000 cost: 0.588533024
#  Training accuracy: 0.800
#  Test accuracy: 0.444
# Epoch: 100/1000 cost: 0.552061776
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 110/1000 cost: 0.537217483
#  Training accuracy: 0.800
#  Test accuracy: 0.556
# Epoch: 120/1000 cost: 0.546461110
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: 130/1000 cost: 0.505996898
#  Training accuracy: 0.700
#  Test accuracy: 0.556
# Epoch: 140/1000 cost: 0.495907933
#  Training accuracy: 0.700
#  Test accuracy: 0.500
# Epoch: 150/1000 cost: 0.534719969
#  Training accuracy: 0.700
#  Test accuracy: 0.556
# Epoch: 160/1000 cost: 0.513395478
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 170/1000 cost: 0.478472695
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: 180/1000 cost: 0.517475565
#  Training accuracy: 0.800
#  Test accuracy: 0.556
# Epoch: 190/1000 cost: 0.485752508
#  Training accuracy: 0.800
#  Test accuracy: 0.444
# Epoch: 200/1000 cost: 0.515886277
#  Training accuracy: 0.800
#  Test accuracy: 0.611
# Epoch: 210/1000 cost: 0.499649867
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 220/1000 cost: 0.472772673
#  Training accuracy: 0.700
#  Test accuracy: 0.611
# Epoch: 230/1000 cost: 0.451913580
#  Training accuracy: 0.800
#  Test accuracy: 0.556
# Epoch: 240/1000 cost: 0.479279583
#  Training accuracy: 0.700
#  Test accuracy: 0.556
# Epoch: 250/1000 cost: 0.453433091
#  Training accuracy: 0.900
#  Test accuracy: 0.611
# Epoch: 260/1000 cost: 0.455181931
#  Training accuracy: 0.900
#  Test accuracy: 0.611
# Epoch: 270/1000 cost: 0.430772195
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: 280/1000 cost: 0.451103106
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: 290/1000 cost: 0.454624414
#  Training accuracy: 0.900
#  Test accuracy: 0.611
# Epoch: 300/1000 cost: 0.455677142
#  Training accuracy: 0.800
#  Test accuracy: 0.611
# Epoch: 310/1000 cost: 0.482660721
#  Training accuracy: 0.600
#  Test accuracy: 0.556
# Epoch: 320/1000 cost: 0.482767885
#  Training accuracy: 0.800
#  Test accuracy: 0.611
# Epoch: 330/1000 cost: 0.473389422
#  Training accuracy: 0.700
#  Test accuracy: 0.611
# Epoch: 340/1000 cost: 0.471625254
#  Training accuracy: 0.900
#  Test accuracy: 0.667
# Epoch: 350/1000 cost: 0.387609541
#  Training accuracy: 0.900
#  Test accuracy: 0.611
# Epoch: 360/1000 cost: 0.395270055
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 370/1000 cost: 0.377154971
#  Training accuracy: 0.900
#  Test accuracy: 0.667
# Epoch: 380/1000 cost: 0.453811030
#  Training accuracy: 0.900
#  Test accuracy: 0.611
# Epoch: 390/1000 cost: 0.377268990
#  Training accuracy: 1.000
#  Test accuracy: 0.611
# Epoch: 400/1000 cost: 0.451625079
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 410/1000 cost: 0.406180809
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: 420/1000 cost: 0.397555699
#  Training accuracy: 0.900
#  Test accuracy: 0.556
# Epoch: 430/1000 cost: 0.387203733
#  Training accuracy: 1.000
#  Test accuracy: 0.556
# Epoch: